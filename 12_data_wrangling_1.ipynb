# %% [markdown]
# <a href="https://colab.research.google.com/github/ayportella/02_data_analytics/blob/main/12_data_wrangling_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Data Wrangling I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>DataFrame Pandas;</li>
#   <li>Selecão e Filtros;</li>
#   <li>Inserção, Deleção e Atualização.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Fortune 500

# %% [markdown]
# O [Fortune 500](https://fortune.com/fortune500/2021/search/) é uma ranking anual compilado pela revista Fortune das 500 maiores empresas dos EUA.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O arquivo `fortune.html` contem o código fonte em HTML da página com as 100 primeiras empresas do ranking. **Carregue-o na máquina virtual do Google Colab**.

# %% [markdown]
# Utilize o pacote Python `beautifulsoup4` para extrair todas as 100 empresas do arquivo `fortune.html` providenciado. Salve os dados extraidos no arquivo `fortune.csv` separado por `;`. Exemplo das três primeiras linhas (sem o cabeçalho):
#
# ```
# 1;Walmart;$559,151;6.7%;$13,510;-9.2%;$252,496;$382,642.8;2,300,000
# 2;Amazon;$386,064;37.6%;$21,331;84.1%;$321,195;$1,558,069.6;1,298,000
# 3;Apple;$274,515;5.5%;$57,411;3.9%;$323,888;$2,050,665.9;147,000
# ```
#
# **Dica**: Utilize os código abaixo para ajudar na extração dos dados.
#
# **Dica**: Você não precisa extrair o cabeçalho da tabela, utilize o nome das colunas armazenados na variável `header` abaixo.

# %%
#carregando o arquivo fortune.html no google colab
import requests
from requests.exceptions import HTTPError

conteudo = None
URL = 'https://fortune.com/fortune500/2021/search'

try:
  resposta = requests.get(URL)
  resposta.raise_for_status()
except HTTPError as exc:
  print(exc)
else:
  conteudo = resposta.text

  print(conteudo)
# Out:
# <!doctype html>
# <html lang="en"  >
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#
#     <link rel="shortcut icon" href="https://content.fortune.com/wp-content/uploads/2020/02/favicon_144.ico">
#     <!-- @todo perhaps make GTM ID an env var instead of a setting, use here instead of hard-coding. -->
#
#     <!-- 3rd party dns-prefetching -->
#     <link rel="preconnect" href="https://cdn.ampproject.org" crossorigin>
#     <link rel="preconnect" href="https://buy.tinypass.com" crossorigin>
#     <link rel="preconnect" href="https://static.adsafeprotected.com" crossorigin>
#     <link rel="preconnect" href="https://content.fortune.com" crossorigin>
#     <link rel="preconnect" href="https://download.fortune.com" crossorigin>
#     <link rel="preconnect" href="https://fonts.googleapis.com" crossorigin>
#     <link rel="preconnect" href="https://www.google-analytics.com" crossorigin>
# ...

# %%
# %%writefile fortune.html
# <!doctype html>
# <html lang="en"  >
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#
#     <link rel="shortcut icon" href="https://content.fortune.com/wp-content/uploads/2020/02/favicon_144.ico">
#     <!-- @todo perhaps make GTM ID an env var instead of a setting, use here instead of hard-coding. -->
#
#     <!-- 3rd party dns-prefetching -->
#     <link rel="preconnect" href="https://cdn.ampproject.org" crossorigin>
#     <link rel="preconnect" href="https://buy.tinypass.com" crossorigin>
#     <link rel="preconnect" href="https://static.adsafeprotected.com" crossorigin>
#     <link rel="preconnect" href="https://content.fortune.com" crossorigin>
#     <link rel="preconnect" href="https://download.fortune.com" crossorigin>
#     <link rel="preconnect" href="https://fonts.googleapis.com" crossorigin>
#     <link rel="preconnect" href="https://www.google-analytics.com" crossorigin>
#     <link rel="preconnect" href="https://www.googletagmanager.com" crossorigin>
#     <link rel="preconnect" href="https://sb.scorecardresearch.com" crossorigin>
#     <link rel="preconnect" href="https://srv.pixel.parsely.com" crossorigin>
#     <link rel="preconnect" href="https://csi.gstatic.com" crossorigin>
#     <link rel="preconnect" href="https://cdn.parsely.com" crossorigin>
#     <link rel="preconnect" href="https://consent.trustarc.com" crossorigin>
#     <link rel="preconnect" href="https://trustarc.mgr.consensu.org" crossorigin>
#     <link rel="preconnect" href="https://imasdk.googleapis.com" crossorigin>
#     <link rel="preconnect" href="https://securepubads.g.doubleclick.net" crossorigin>
#     <link rel="preconnect" href="https://ad.doubleclick.net" crossorigin>
#     <link rel="preconnect" href="https://static.doubleclick.net" crossorigin>
#     <link rel="preconnect" href="https://cdn.tinypass.com" crossorigin>
#     <link rel="preconnect" href="https://tag.bounceexchange.com" crossorigin>
#     <link rel="preconnect" href="https://www.dianomi.com" crossorigin>
#     <link rel="preconnect" href="https://z.moatads.com" crossorigin>
#     <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
#     <link rel="preconnect" href="https://www.queryly.com/js/queryly.v4.min.js" crossorigin>
#
#
#
#     <link rel="dns-prefetch" href="https://ad.clipcentric.com" crossorigin>
#     <link rel="dns-prefetch" href="https://tr.clipcentric.com" crossorigin>
#     <link rel="dns-prefetch" href="https://clipcentric-a.akamaihd.net" crossorigin>
#     <link rel="dns-prefetch" href="https://pubads.g.doubleclick.net" crossorigin>
#     <link rel="dns-prefetch" href="https://jadserve.postrelease.com" crossorigin>
#     <link rel="dns-prefetch" href="https://s.ntv.io" crossorigin>
#     <link rel="dns-prefetch" href="https://px.ads.linkedin.com" crossorigin>
#     <link rel="dns-prefetch" href="https://p.adsymptotic.com" crossorigin>
#     <link rel="dns-prefetch" href="https://pixel.adsafeprotected.com" crossorigin>
#     <link rel="dns-prefetch" href="https://cdn3.doubleverify.com" crossorigin>
#     <link rel="dns-prefetch" href="https://www.facebook.com" crossorigin>
#     <link rel="dns-prefetch" href="https://connect.facebook.net" crossorigin>
#     <link rel="dns-prefetch" href="https://ajax.cloudflare.com" crossorigin>
#     <link rel="dns-prefetch" href="https://ads.revjet.com" crossorigin>
#     <link rel="dns-prefetch" href="https://tpc.googlesyndication.com" crossorigin>
#     <link rel="dns-prefetch" href="https://ovp.iris.tv" crossorigin>
#     <link rel="dns-prefetch" href="https://vjs.zencdn.net" crossorigin>
#     <link rel="dns-prefetch" href="https://pagead2.googlesyndication.com" crossorigin>
#
#     <!-- Font preload -->
#     <link rel="preload" href="/static/css/fonts.css?3-38" as="style">
#     <link rel="stylesheet" href="/static/css/fonts.css?3-38">
#     <link rel="preload" href="/static/media/GraphikCondensed-Medium-Web.woff2" as="font" type="font/woff2" crossorigin>
#     <link rel="preload" href="/static/media/GraphikCondensed-Regular-Web.woff2" as="font" type="font/woff2" crossorigin>
#     <link rel="preload" href="/static/media/GraphikCompact-Medium-Web.woff2" as="font" type="font/woff2" crossorigin>
#     <link rel="preload" href="/static/media/GraphikCondensed-Semibold-Web.woff2" as="font" type="font/woff2" crossorigin>
#     <!-- End font preload -->
#
#     <!-- forEach Polyfill for IE11 -->
#     <script src="https://polyfill.io/v3/polyfill.min.js?features=NodeList.prototype.forEach"></script>
#     <!-- End forEach Polyfill for IE11-->
#
#     <script defer src='https://www.google-analytics.com/analytics.js'></script>
#
#     <!-- Primary GTM container -->
#     <script
#       src="https://www.googletagmanager.com/gtm.js?id=GTM-N68KRG3"
#       async
#     >
#     </script>
#     <script>
#       (function(w, l){
#         w[l]=w[l]||[];
#         w[l].push({
#           'gtm.start': new Date().getTime(),
#           event: 'gtm.js',
#         });
#       })(window, 'dataLayer');
#     </script>
#     <!-- End primary GTM container -->
#
#     <script async src="//www.googletagservices.com/tag/js/gpt.js"></script>
#     <script>var googletag = googletag || {}; googletag.cmd = googletag.cmd || []</script>
#
#
#
#
#
#     <title data-react-helmet="true">Fortune 500 list of companies 2021 | Fortune</title>
#     <meta data-react-helmet="true" name="msapplication-TileColor" content="#ffc40d"/><meta data-react-helmet="true" name="theme-color" content="#ffffff"/><meta data-react-helmet="true" name="description" content="This year’s Fortune 500 marks the 67th running of the list."/><meta data-react-helmet="true" name="keywords" content=""/><meta data-react-helmet="true" property="og:url" content="https://fortune.com/fortune500/2021/"/><meta data-react-helmet="true" property="og:type" content="article"/><meta data-react-helmet="true" property="og:title" content="Fortune 500"/><meta data-react-helmet="true" property="og:description" content="This year’s Fortune 500 marks the 67th running of the list."/><meta data-react-helmet="true" property="og:site_name" content="Fortune"/><meta data-react-helmet="true" property="fb:pages" content="56501027948"/><meta data-react-helmet="true" property="og:image" content="https://content.fortune.com/wp-content/uploads/2021/05/TTL.0721.Fortune-500-list-logo-featured.jpg?resize=1200,600"/><meta data-react-helmet="true" property="og:width" content="1024"/><meta data-react-helmet="true" property="og:height" content="683"/><meta data-react-helmet="true" name="twitter:card" content="summary_large_image"/><meta data-react-helmet="true" name="twitter:title" content="Fortune 500"/><meta data-react-helmet="true" name="twitter:description" content="This year’s Fortune 500 marks the 67th running of the list."/><meta data-react-helmet="true" name="twitter:image" content="https://content.fortune.com/wp-content/uploads/2021/05/TTL.0721.Fortune-500-list-logo-featured.jpg?resize=1200,600"/><meta data-react-helmet="true" name="twitter:url" content="https://fortune.com/fortune500/2021/"/>
#     <link data-react-helmet="true" rel="shortcut icon" href="data:image/vnd.microsoft.icon;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="57x57" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="60x60" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="72x72" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="76x76" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="114x114" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="120x120" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="144x144" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="152x152" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="apple-touch-icon" sizes="180x180" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="icon" type="image/png" sizes="32x32" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="icon" type="image/png" sizes="16x16" href="data:image/png;base64,..."/><link data-react-helmet="true" rel="manifest" href="https://fortune.com/static/media/site.147580f0.webmanifest"/><link data-react-helmet="true" rel="mask-icon" href="data:image/svg+xml;base64,..." color="#5bbad5"/><link data-react-helmet="true" rel="preload" href="/static/media/Graphik-Bold-Web.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link data-react-helmet="true" rel="preload" href="/static/media/GraphikCondensed-Bold-Web.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link data-react-helmet="true" rel="preload" href="/static/media/SaolText-Bold.woff2" as="font" type="font/woff2" crossorigin="anonymous"/><link data-react-helmet="true" rel="canonical" href="https://fortune.com/fortune500/2021/"/>
#
#
#
#
#     <style id="critical-css">.wp-caption{width:100%!important}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;box-sizing:border-box;font-size:100%;font:inherit;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block}html{background-color:#fff}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.app__skipLink--z5h7i{border:0;clip:rect(1px,1px,1px,1px);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;word-wrap:normal;align-items:center;display:flex;justify-content:center;left:0;text-transform:uppercase;top:0;z-index:9999}.app__skipLink--z5h7i:active,.app__skipLink--z5h7i:focus{background-color:#fff;border:2px solid #000;clip:auto;-webkit-clip-path:none;clip-path:none;color:#000;height:2.5rem;margin:0;padding:0;width:12.5rem}#teconsent{display:flex;justify-content:center;margin:1.25rem 0}#wpstats{display:block;margin:.625rem auto}.dianomi_context{margin:auto;max-width:55rem}html:after,html:before{z-index:1010!important}.wp-caption{width:100%!important}.header__wrapper--3U2jz{background-color:#fff;display:flex;flex-direction:column;width:100%;z-index:10}@media (min-width:64rem){.header__wrapper--3U2jz{display:block;position:static}}.header__wrapper--3U2jz span{border:0;clip:rect(1px,1px,1px,1px);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;word-wrap:normal}.header__placeholder--2_VsK{min-height:3rem;width:100%;z-index:-2}@media (min-width:48rem){.header__placeholder--2_VsK{display:block;min-height:3rem;position:absolute;top:0}}@media (min-width:64rem){.header__placeholder--2_VsK{display:none}}.data-store .header__placeholder--2_VsK{margin-bottom:0}@media (min-width:48rem){.header__placeholder--2_VsK.header__withoutAd--1276a{min-height:10rem}}.header__placeholder--2_VsK.header__hideTopDiv--1TfUi{display:none}.header__bottomContent--28Yr8{align-items:center;background-color:#fff;border-bottom:1px solid #d7d7d9;display:flex;height:100%;justify-content:space-between;padding-left:1rem;padding-right:1rem}@media (min-width:48rem){.header__bottomContent--28Yr8{margin-left:1.5rem!important;margin-right:1.5rem!important;padding:0!important}}@media (min-width:90rem){.header__bottomContent--28Yr8{margin-left:3rem!important;margin-right:3rem!important}}.header__center--2JC3n{margin-left:auto;margin-right:auto;margin-top:1.25rem}.header__bottomMenu--gkHu_{align-items:center;display:flex;justify-content:space-between}@media (min-width:64rem){.header__bottomMenu--gkHu_{height:100%;justify-content:normal;margin:0}}.header__logo--2A4EQ svg{fill:#000}.header__bottom--14eUZ{background-color:#fff;position:sticky;top:0;width:100%;z-index:1002}@media (min-width:48rem){.header__bottom--14eUZ{height:100%;padding:0}}@media (min-width:64rem){.header__bottom--14eUZ{height:4.5rem}}.header__bottomLeft--19Wnh,.header__bottomRight--3f8BV,.header__rightMenu--1u3Vj{align-items:center;display:flex;height:100%}.header__bottomLeft--19Wnh,.header__bottomRight--3f8BV{position:relative}.header__rightMenuWrapper--IQzQ5{align-items:flex-end;align-self:flex-end;display:none}.header__bottomCenter--M0puQ{z-index:1}@media (min-width:64rem){.header__bottomCenter--M0puQ{margin:0}}.header__logoCenter--1PNId svg,.header__logoLeft--2flqO svg{height:1.25rem;width:5.125rem}.header__bottomRight--3f8BV{align-items:center;display:flex}.header__bottomRight--3f8BV>div{margin-left:1rem}@media (min-width:64rem){.header__bottomRight--3f8BV>div{margin-bottom:.5rem;margin-left:.5rem;margin-top:.5rem}}@media (min-width:80rem){.header__bottomRight--3f8BV>div{margin-left:1rem}}@media (min-width:48rem){.header__bottomRight--3f8BV>div:first-child{margin-left:0}}.header__menu--2nvJG{display:none}@media (min-width:64rem){.header__menu--2nvJG{display:block}}.header__navScrolled--2QREA,.header__navTop--9Pzf-{height:calc(100vh - 3rem);position:absolute;top:3rem;width:100%;z-index:1001}.header__navScrolled--2QREA>button,.header__navTop--9Pzf->button{display:none}@media (min-width:48rem){.header__navScrolled--2QREA,.header__navTop--9Pzf-{max-height:calc(50% - 3.813rem);top:3.9rem}}.header__disableMenuWrapper--CQz5B{pointer-events:none}.header__hamburger--1_xdF{-webkit-appearance:none;-moz-appearance:none;appearance:none;background-color:transparent;border-radius:0;font:inherit;margin:0;padding:0;border:none;outline:none}@media (min-width:64rem){.header__hamburger--1_xdF{display:none}}.header__hamburger--1_xdF span{border:0;clip:rect(1px,1px,1px,1px);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;word-wrap:normal}.header__hamburgerIcon--1SXwQ{align-items:center;display:flex;flex-direction:column;justify-content:center;padding:1rem 1rem 1rem 0}@media (min-width:48rem){.header__hamburgerIcon--1SXwQ{padding:1rem 1.5rem 1rem 0}}.header__bar1--2u7gl,.header__bar2--3XgcX,.header__bar3--2Y4rb{background-color:#000;border-radius:.125rem;height:.125rem;margin:.125rem;width:1rem}.header__adWrapper--hK8Xq{background-color:#fff;display:block;transition:transform .3s ease-in-out;width:100%}@media (min-width:64rem){.header__slideUpLarge--dJYzB{transform:translateY(0)}}.wp-caption{width:100%!important}.largeHeader__wrapper--2hufJ{pointer-events:auto}.wp-caption{width:100%!important}.smallHeader__titleWrapper--1glhC{display:none;max-height:1.25rem}@media (min-width:48rem){.smallHeader__titleWrapper--1glhC{display:block;max-width:22.5rem}}@media (min-width:64rem){.smallHeader__titleWrapper--1glhC{display:block;max-width:30rem}}.smallHeader__logoCenterWrapper--1Sa_6{transform:translate(-50%,-50%)}.page__placeholder--3S_se{min-height:3rem}.adTag__Footer--lR6s8,.adTag__Leaderboard--2bO6j{margin:0 auto;padding:.625rem;width:100%}@media (min-width:48rem){.adTag__Footer--lR6s8,.adTag__Leaderboard--2bO6j{min-height:7rem}}.adTag__Leaderboard--2bO6j{background-color:hsla(0,0%,100%,.95);border-top:0;bottom:0;margin:auto;position:fixed;width:100%;z-index:200}@media (min-width:48rem){.adTag__Leaderboard--2bO6j{display:flex;min-height:15.625rem;position:static;width:100%}.adTag__Leaderboard--2bO6j>div:first-child{margin:auto;position:sticky;top:.625rem}}@media (min-width:64rem){.adTag__Leaderboard--2bO6j{min-height:18.75rem}}.adTag__LeaderboardHide--2Ktyr{display:none;opacity:0}.adTag__Footer--lR6s8{margin-bottom:-1px}.adTag__RightRailFlex--25hRc{margin-bottom:2.25rem;width:100%}.adTag__longformrrf--2muVO{flex:33%}@media (min-width:64rem){.adTag__longformrrf--2muVO div{position:sticky!important;top:7.25rem}}.adTag__articlerrf--1w1Nw{margin-bottom:.5rem;min-height:250px;min-width:300px}.adTag__articlerrf--1w1Nw:last-child{flex:auto}@media (min-width:64rem){.adTag__articlerrf--1w1Nw:last-child div{position:sticky!important;top:7.25rem}}.adTag__InStream--RMS2K{margin-bottom:2.25rem;min-height:15.625rem;width:100%}@media (min-width:48rem){.adTag__InStream--RMS2K{min-height:5.625rem}}.adTag__Outstream--2VEt4{min-height:0;min-width:0}.adTag__Homepage-InStream--2AoMT{margin-bottom:1.5rem;min-height:15.625rem}@media (min-width:48rem){.adTag__Homepage-InStream--2AoMT{min-height:5.625rem}}@media (min-width:64rem){.adTag__Homepage-InStream--2AoMT{margin-bottom:3rem}}.adTag__Newsletter-InStream--27cLK{margin-bottom:1.5rem}@media (min-width:64rem){.adTag__Newsletter-InStream--27cLK{margin-bottom:3rem}}.container__container--a5NXK{margin-left:auto;margin-right:auto}.container__padding--2mKn5{padding-left:1rem;padding-right:1rem}@media (min-width:48rem){.container__padding--2mKn5{padding-left:1.5rem;padding-right:1.5rem}}@media (min-width:80rem){.container__padding--2mKn5{padding-left:3rem;padding-right:3rem}}.container__xxl--3SCes{max-width:90rem}.container__xl--3mlsX,.container__xxl--3SCes{}.container__xl--3mlsX{max-width:80rem}.container__lg--1xAKP{max-width:64rem}.container__lg--1xAKP,.container__md--2DYiW{}.container__md--2DYiW{max-width:48rem}.container__sm--2sjn1{max-width:32rem}.menu__header--3hepL{align-items:center;height:100%;position:relative}.menu__header--3hepL,.menu__header--3hepL>:first-child{display:flex}.menu__header--3hepL>:first-child>ul{display:none}.menu__header--3hepL>:first-child>ul a{color:#000;line-height:1rem}.menu__header--3hepL>:first-child>ul a:focus,.menu__header--3hepL>:first-child>ul a:hover{color:#007b9d}.menu__header--3hepL>:first-child:after{background-color:#000;background-size:100%;content:" ";display:block;-webkit-mask-image:url(...);mask-image:url(...);-webkit-mask-position:center;mask-position:center;-webkit-mask-repeat:no-repeat;mask-repeat:no-repeat;-webkit-mask-size:100%;mask-size:100%;pointer-events:none;transform:rotate(90deg);width:.875rem}@media (min-width:64rem){.menu__header--3hepL>:first-child:after{width:1rem}}@media (min-width:80rem){.menu__header--3hepL>:first-child:after{width:1.25rem}}.menu__header--3hepL>:first-child:focus,.menu__header--3hepL>:first-child:hover{color:#007b9d}.menu__header--3hepL>:first-child:focus:after,.menu__header--3hepL>:first-child:hover:after{background-color:#007b9d;transform:rotate(-90deg)}.menu__header--3hepL>:first-child:focus ul:first-of-type,.menu__header--3hepL>:first-child:hover ul:first-of-type{background:#f2f2f2;box-shadow:0 .125rem .25rem .125rem rgba(0,0,0,.2);display:flex;flex-direction:column;justify-content:space-between;margin:auto;padding:1rem;position:absolute;top:1.188rem;width:21.438rem;z-index:100}.menu__header--3hepL>:first-child:focus ul:first-of-type li,.menu__header--3hepL>:first-child:hover ul:first-of-type li{align-items:center;border-top:1px solid #d7d7d9;display:flex;height:100%;padding:.5rem 0;width:100%}.menu__header--3hepL>:first-child:focus ul:first-of-type li>a,.menu__header--3hepL>:first-child:hover ul:first-of-type li>a{font-size:.875rem}.menu__header--3hepL>:first-child:focus ul:first-of-type>li:first-child,.menu__header--3hepL>:first-child:hover ul:first-of-type>li:first-child{border-style:none;padding:0 0 .5rem}.menu__header--3hepL>:first-child:focus ul:first-of-type>li:first-child>a,.menu__header--3hepL>:first-child:hover ul:first-of-type>li:first-child>a{font-size:.75rem}.menu__header--3hepL>:first-child:focus ul:first-of-type>li:first-child:before,.menu__header--3hepL>:first-child:hover ul:first-of-type>li:first-child:before{background-color:#000;background-size:100%;content:" ";display:block;height:.656rem;line-height:.875rem;margin-right:.25rem;margin-top:.063rem;-webkit-mask-image:url(data:image/svg+xml;base64,...);mask-image:url(data:image/svg+xml;base64,...);-webkit-mask-position:center;mask-position:center;-webkit-mask-repeat:no-repeat;mask-repeat:no-repeat;-webkit-mask-size:100%;mask-size:100%;pointer-events:none;transition:background-color 0s;width:.656rem}.menu__header--3hepL>:first-child:focus ul:first-of-type>li:first-child:focus:before,.menu__header--3hepL>:first-child:hover ul:first-of-type>li:first-child:hover:before{background-color:#007b9d;transition-delay:75ms}.menu__header--3hepL>:first-child:focus ul:first-of-type>li:nth-child(2),.menu__header--3hepL>:first-child:hover ul:first-of-type>li:nth-child(2){border-top:none;padding-bottom:.5rem;padding-top:0}.menu__header--3hepL>:first-child:focus ul:first-of-type>li:last-child,.menu__header--3hepL>:first-child:hover ul:first-of-type>li:last-child{padding-bottom:0}.menuItem__wrapper--2F3dl{margin-top:1rem}.menuItem__wrapper--2F3dl:first-child{margin-top:0}@media (min-width:48rem){.menuItem__wrapper--2F3dl{margin-right:1rem;margin-top:0}}@media (min-width:64rem){.menuItem__wrapper--2F3dl{white-space:nowrap}}.menuItem__wrapper--2F3dl a{color:#000;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.75rem;font-weight:500;letter-spacing:.063rem;line-height:1.125rem;text-decoration:none;transition:color .2s linear}.menuItem__wrapper--2F3dl a:focus,.menuItem__wrapper--2F3dl a:hover{color:#007b9d}.menuItem__header--1S8Gp{font-weight:500;height:100%;letter-spacing:1px;margin-bottom:0;margin-right:0;padding:0 .25rem;text-transform:uppercase}.menuItem__header--1S8Gp a,.menuItem__header--1S8Gp span{color:#000;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.875rem;font-weight:500}@media (min-width:80rem){.menuItem__header--1S8Gp a,.menuItem__header--1S8Gp span{font-size:1rem}}.menuItem__header--1S8Gp:first-child{padding-left:1.5rem}@media (min-width:64rem){.menuItem__header--1S8Gp:first-child{padding-left:1rem}}@media (min-width:80rem){.menuItem__header--1S8Gp:first-child{padding-left:2rem}}.menuItem__header--1S8Gp:first-child:focus>a,.menuItem__header--1S8Gp:first-child:hover>a{color:#007b9d}@media (min-width:80rem){.menuItem__header--1S8Gp{padding:0 .75rem}}.menuItem__header--1S8Gp:last-child{display:flex;position:relative}.menuItem__header--1S8Gp:last-child>ul{display:none}.menuItem__header--1S8Gp:last-child>ul a{color:#000;line-height:1rem}.menuItem__header--1S8Gp:last-child>ul a:focus,.menuItem__header--1S8Gp:last-child>ul a:hover{color:#007b9d}.menuItem__header--1S8Gp:last-child:after{background-color:#000;background-size:100%;content:" ";display:block;-webkit-mask-image:url(...);mask-image:url(...);-webkit-mask-position:center;mask-position:center;-webkit-mask-repeat:no-repeat;mask-repeat:no-repeat;-webkit-mask-size:100%;mask-size:100%;pointer-events:none;transform:rotate(90deg);width:.875rem}@media (min-width:64rem){.menuItem__header--1S8Gp:last-child:after{width:1rem}}@media (min-width:80rem){.menuItem__header--1S8Gp:last-child:after{width:1.25rem}}.menuItem__header--1S8Gp:last-child:focus,.menuItem__header--1S8Gp:last-child:hover{color:#007b9d}.menuItem__header--1S8Gp:last-child:focus:after,.menuItem__header--1S8Gp:last-child:hover:after{background-color:#007b9d;transform:rotate(-90deg)}.menuItem__header--1S8Gp:last-child:focus>a,.menuItem__header--1S8Gp:last-child:hover>a{color:#007b9d}.menuItem__header--1S8Gp:last-child:focus ul:first-of-type,.menuItem__header--1S8Gp:last-child:hover ul:first-of-type{background:#f2f2f2;box-shadow:0 .125rem .25rem .125rem rgba(0,0,0,.2);display:flex;flex-direction:column;justify-content:space-between;margin:auto;padding:.5rem 1rem 1rem;position:absolute;right:.5rem;top:1.188rem;width:12.5rem;z-index:100}.menuItem__header--1S8Gp:last-child:focus ul:first-of-type li,.menuItem__header--1S8Gp:last-child:hover ul:first-of-type li{align-items:center;display:flex;height:100%;padding:.5rem 0;width:100%}.menuItem__header--1S8Gp:last-child:focus ul:first-of-type li>a,.menuItem__header--1S8Gp:last-child:hover ul:first-of-type li>a{font-size:.875rem}.menuItem__header--1S8Gp:last-child:focus ul:first-of-type>li,.menuItem__header--1S8Gp:last-child:hover ul:first-of-type>li{border-top:1px solid #d7d7d9}.menuItem__header--1S8Gp:last-child:focus ul:first-of-type>li:first-child,.menuItem__header--1S8Gp:last-child:hover ul:first-of-type>li:first-child{border-top:0}.menuItem__header--1S8Gp:last-child:focus ul:first-of-type>li:last-child,.menuItem__header--1S8Gp:last-child:hover ul:first-of-type>li:last-child{padding-bottom:0}.menuItem__rankings--3ITO0{font-weight:600;letter-spacing:1px;margin-bottom:0;padding:0 .5rem;text-transform:uppercase}.menuItem__rankings--3ITO0 a{color:#2d2d2e;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:1rem;font-weight:600;height:1rem}.wp-caption{width:100%!important}.headerSearch__searchOverlay--30Q_F{background-color:#fff;height:100vh;left:0;overflow:auto;position:fixed;top:0;width:100vw;z-index:1003}.headerSearch__title--1Qylu{color:#000;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:2.125rem;font-weight:500;letter-spacing:.016rem;margin-top:1rem;text-align:center}@media (min-width:48rem){.headerSearch__title--1Qylu{font-size:3rem;margin-top:3rem}}@media (min-width:90rem){.headerSearch__title--1Qylu{font-size:6rem;letter-spacing:-.094rem;opacity:.9599999785423279}}.headerSearch__subtitle--2Uel7{color:#000;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:2.125rem;font-weight:500;letter-spacing:.016rem;margin-top:2rem;padding:0 1rem;text-align:left}@media (min-width:48rem){.headerSearch__subtitle--2Uel7{font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:3rem;margin:2rem 0 0;padding:0 1.5rem}}@media (min-width:90rem){.headerSearch__subtitle--2Uel7{font-size:3.75rem;letter-spacing:-.031rem;margin-top:3rem;padding:0}}.headerSearch__content--14HMQ,.headerSearch__formWrapper--3EM01{align-items:center;display:flex}.headerSearch__formWrapper--3EM01{display:block;height:100vh;margin:1rem auto auto;width:100vw}@media (min-width:48rem){.headerSearch__formWrapper--3EM01{margin-top:2rem}}@media (min-width:90rem){.headerSearch__formWrapper--3EM01{max-width:69.5rem}}.headerSearch__closeButton--1WCGd,.headerSearch__openButton--3wTuY{-webkit-appearance:none;-moz-appearance:none;appearance:none;background-color:transparent;border:none;border-radius:0;font:inherit;margin:0;padding:0;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.875rem;font-weight:500;justify-content:center;transition:color .2s linear}.headerSearch__closeButton--1WCGd,.headerSearch__closeButton--1WCGd div,.headerSearch__openButton--3wTuY,.headerSearch__openButton--3wTuY div{align-items:center;color:#000;display:flex;letter-spacing:.063rem}.headerSearch__closeButton--1WCGd div,.headerSearch__openButton--3wTuY div{font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:1rem;font-weight:500;line-height:1.5rem;line-height:1.188rem;text-align:left;width:100%}.headerSearch__closeButton--1WCGd div:before,.headerSearch__openButton--3wTuY div:before{background-color:#000;background-size:100%;content:" ";display:block;height:.875rem;letter-spacing:.01rem;margin-top:.125rem;-webkit-mask-image:url(...);mask-image:url(...);-webkit-mask-position:center;mask-position:center;-webkit-mask-repeat:no-repeat;mask-repeat:no-repeat;-webkit-mask-size:100%;mask-size:100%;pointer-events:none;transform:rotate(180deg);width:.875rem}@media (min-width:80rem){.headerSearch__closeButton--1WCGd,.headerSearch__openButton--3wTuY{font-size:1rem}}.headerSearch__closeButton--1WCGd:focus,.headerSearch__closeButton--1WCGd:hover,.headerSearch__openButton--3wTuY:focus,.headerSearch__openButton--3wTuY:hover{color:#007b9d}.headerSearch__closeButton--1WCGd{margin:1rem 1rem 0}@media (min-width:48rem){.headerSearch__closeButton--1WCGd{margin:2rem 1.5rem 0}}@media (min-width:90rem){.headerSearch__closeButton--1WCGd{margin:5rem 3rem 0}}.headerSearch__form--2tPB1{margin:auto;padding:0 1rem;width:100%}@media (min-width:48rem){.headerSearch__form--2tPB1{padding:0 1.5rem}}@media (min-width:90rem){.headerSearch__form--2tPB1{padding:0}}.headerSearch__input--leJto{margin-bottom:0;width:100%}.headerSearch__input--leJto [type=text]{border:1px solid #000;color:#000;font-family:Graphik,Helvetica,Verdana,sans-serif;font-size:1rem;line-height:1.188rem;padding:1rem;width:100%}@media (min-width:48rem){.headerSearch__input--leJto [type=text]{padding:1.5rem}}.headerSearch__input--leJto [type=text]:focus{border:1px solid #007b9d;outline:none}.headerSearch__input--leJto label{border:0;clip:rect(1px,1px,1px,1px);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px;word-wrap:normal}.headerSearch__openButtonSearch--3q6mX{border-bottom:1px solid #000;display:none;margin-top:.438rem;text-align:left}.headerSearch__openButtonSearch--3q6mX label{padding-bottom:5px;width:100%}.headerSearch__openButtonSearch--3q6mX label span{margin-left:20px}.headerSearch__openButtonSearch--3q6mX svg{position:absolute;width:16px}.headerSearch__openButtonSearch--3q6mX svg path{fill:#000}@media (min-width:80rem){.headerSearch__openButtonSearch--3q6mX{width:8.25rem}}.header__bottomRight--3f8BV>div{position:relative}.headerSearch__tag--2438f{color:#4a90e2;display:none;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.75rem;font-weight:500;left:-2.375rem;letter-spacing:.063rem;padding-top:.125rem;position:absolute;top:.375rem}.headerSearch__tag--2438f:before{background-color:#4a90e2;border-radius:.125rem;content:"";display:inline-block;height:.25rem;margin-bottom:.125rem;margin-right:.25rem;width:.25rem}@media (min-width:64rem){.headerSearch__tag--2438f{left:0;top:1.75rem}}.headerSearch__tag--2438f:focus,.headerSearch__tag--2438f:hover{cursor:default}.headerSearch__tag--2438f:focus+.headerSearch__tagContainer--2nXOp,.headerSearch__tag--2438f:hover+.headerSearch__tagContainer--2nXOp{display:block}.headerSearch__tagContainer--2nXOp{background-color:#fff;border:1px solid;display:none;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.75rem;left:-2.375rem;letter-spacing:.063rem;line-height:1.125rem;margin-top:.375rem;padding:.5rem;position:absolute;width:8.125rem}@media (min-width:64rem){.headerSearch__tagContainer--2nXOp{left:0;top:2.625rem;width:13rem}}.headerAccount__wrapper--2w_kq{align-items:center;display:flex;height:2.813rem;text-decoration:none}@media (max-width:425px){.tp-iframe-wrapper{text-align:center;width:100%!important}}.headerAccount__text1--th-Rr{color:#000;cursor:pointer;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.875rem;font-weight:500;letter-spacing:.063rem;text-decoration:none;text-transform:uppercase;transition:color .2s linear}.headerAccount__text1--th-Rr:focus,.headerAccount__text1--th-Rr:hover{color:#007b9d}@media (min-width:80rem){.headerAccount__text1--th-Rr{font-size:1rem}}.headerAccount__favorites--3DD1N{border-bottom:1px solid #d1d1d6;color:#000;cursor:pointer;display:block;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.875rem;font-weight:500;letter-spacing:.063rem;margin-bottom:.5rem;padding-bottom:.5rem;text-decoration:none;text-transform:uppercase;transition:color .2s linear}.headerAccount__favorites--3DD1N:focus,.headerAccount__favorites--3DD1N:hover{color:#007b9d}@media (min-width:80rem){.headerAccount__favorites--3DD1N{font-size:1rem}}.headerAccount__mobileMyAccount--3e6Vc{position:relative}.headerAccount__mobileMyAccount--3e6Vc>button{background-color:#fff;border:none;outline:none;padding:0}.headerAccount__mobileMyAccount--3e6Vc>button:focus,.headerAccount__mobileMyAccount--3e6Vc>button:hover{cursor:pointer}.headerAccount__mobileMyAccount--3e6Vc svg{height:18px;margin-top:2px;width:18px}.headerAccount__mobileUserMenu--ww8yg{background-color:#fff;box-shadow:0 .125rem .25rem .125rem rgba(0,0,0,.2);display:flex;flex-direction:column;padding:1rem;position:absolute;right:0;width:130px}.headerAccount__mobileUserMenu--ww8yg>a,.headerAccount__mobileUserMenu--ww8yg>span{align-items:center;color:#000;display:flex;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.875rem;font-weight:500;letter-spacing:.044rem;line-height:1rem;padding-top:.5rem}.headerAccount__mobileUserMenu--ww8yg>a:first-child,.headerAccount__mobileUserMenu--ww8yg>span:first-child{padding-top:0}.headerAccount__myAccount--26qlD{align-items:center;display:flex;height:100%;position:relative;white-space:nowrap}.headerAccount__myAccount--26qlD:after{background-color:#000;background-size:100%;content:" ";display:block;height:.75rem;-webkit-mask-image:url(...);mask-image:url(...);-webkit-mask-position:center;mask-position:center;-webkit-mask-repeat:no-repeat;mask-repeat:no-repeat;-webkit-mask-size:100%;mask-size:100%;pointer-events:none;transform:rotate(90deg);width:.875rem}@media (min-width:64rem){.headerAccount__myAccount--26qlD:after{height:.875rem;width:1rem}}@media (min-width:80rem){.headerAccount__myAccount--26qlD:after{height:1rem;width:1.25rem}}.headerAccount__myAccount--26qlD:focus:after,.headerAccount__myAccount--26qlD:hover:after{background-color:#007b9d;transform:rotate(-90deg)}.headerAccount__myAccount--26qlD:focus .headerAccount__logOut--2zxMp,.headerAccount__myAccount--26qlD:hover .headerAccount__logOut--2zxMp{display:block}.headerAccount__logOut--2zxMp{background-color:#f2f2f2;box-shadow:0 .125rem .25rem .125rem rgba(0,0,0,.2);display:none;padding:1rem;position:absolute;right:0;top:2rem;width:8.75rem}.headerAccount__logOut--2zxMp>span{color:#000;font-family:Graphik Condensed,Helvetica,Verdana,sans-serif;font-size:.875rem;font-weight:500;letter-spacing:.044rem;line-height:1rem}.headerAccount__headerCTA--690wh{font-size:.875rem!important;margin-left:1rem!important;text-transform:none!important;white-space:nowrap}@media (min-width:80rem){.headerAccount__headerCTA--690wh{font-size:1rem!important}}@media (min-width:90rem){.site-wrapper{margin:auto;width:90rem}}.site-wrapper.longform--background-black{background-color:#000}main{position:relative}#piano-inline{bottom:100px;left:0;position:fixed;width:100%;z-index:999999}@media (min-width:48rem){#piano-inline{bottom:0}}#piano-inline>div>iframe{width:100%!important}#piano-wrapper{background-color:transparent!important;display:none;max-width:90rem;position:absolute;width:100%}.tp-modal .tp-close{border:1px solid #000!important;border-radius:0!important;box-shadow:2px 2px 0 0 #000!important;height:40px!important;width:40px!important}.tp-iframe-wrapper{border:1px solid #000!important;box-shadow:4px 4px 0 0 #000!important}.searchWrapper__wrapper--1MLSI{min-height:100vh}.searchWrapper__content--3nwCz,.searchWrapper__wrapper--1MLSI{display:flex;flex-direction:column}.searchWrapper__headerContainer--10iGf{margin:-2rem 1rem 1.5rem}@media (min-width:48rem){.searchWrapper__headerContainer--10iGf{margin:2rem 1.5rem}}@media (min-width:80rem){.searchWrapper__headerContainer--10iGf{margin:3rem}}.heading__heading--hUYqy a{color:inherit;text-decoration:none}.heading__heading--hUYqy em{font-style:italic}.heading__heading--hUYqy strong{font-weight:700}.heading__graphik--1CaA1{font-family:Graphik,Helvetica,Verdana,sans-serif}.heading__graphikCond--38qNM{font-family:Graphik Condensed,Helvetica,Verdana,sans-serif}.heading__graphikCompact--3Tfmg{font-family:Graphik Compact,Helvetica,Verdana,sans-serif}.heading__saolText--RBEqW{font-family:Saol Text,Helvetica,Verdana,sans-serif}.heading__solano--3q0f7{font-family:Solano Gothic,Helvetica,Verdana,sans-serif;font-weight:400}.heading__step-down-three--1RSmy{font-size:.75rem}.heading__step-down-two--Kr2HY{font-size:.875rem}.heading__step-down-one--3RzTE{font-size:1.125rem}.heading__base--3BL90{font-size:1.25rem}.heading__step-up-one--15Td7{font-size:1.625rem}.heading__step-up-two--2RE5u{font-size:2rem}.heading__step-up-three--4WDO6{font-size:2.125rem}.heading__step-up-four---TbTB{font-size:2.438rem}.heading__step-up-five--2xtCw{font-size:3rem}.heading__step-up-six--3XCFR{compose:heading;font-size:3.75rem}.heading__franchise--3Gdva{font-weight:600;letter-spacing:.016rem}@media (min-width:48rem){.heading__franchise--3Gdva{font-size:3rem}}@media (min-width:64rem){.heading__franchise--3Gdva{font-size:3.75rem}}.footer__wrapper--3kGR7{font-family:Saol Text,Helvetica,Verdana,sans-serif;font-size:.75rem;letter-spacing:.031rem;line-height:.75rem;width:100%}.footer__footerAds--1apOA,.footer__wrapper--3kGR7{display:flex;flex-direction:column}.footer__footerAds--1apOA{padding:1.5rem 1rem}.footer__footerAds--1apOA>div{margin:auto}.footer__footerAds--1apOA>div:first-child{margin-bottom:1.5rem}@media (min-width:48rem){.footer__footerAds--1apOA{margin:1.5rem;padding:0}}@media (min-width:80rem){.footer__footerAds--1apOA{flex-direction:row;justify-content:space-evenly}.footer__footerAds--1apOA>div{margin:0}.footer__footerAds--1apOA>div:first-child{margin-bottom:0;margin-right:1.5rem}}@media (min-width:90rem){.footer__footerAds--1apOA{margin:1.5rem 3rem}.footer__footerAds--1apOA>div:first-child{margin-right:3rem}}.footer__socialWrapper--1J7fo{align-items:center;display:flex;flex-direction:column;padding-top:1.5rem}.footer__socialWrapper--1J7fo .footer__logo--frUrw svg{fill:#000;width:6.25rem}.longform--background-black .footer__socialWrapper--1J7fo .footer__logo--frUrw svg{fill:#fff}.footer__bottomWrapper--AAtR-{border-bottom:1px solid #d7d7d9;display:flex;flex-direction:column;padding:1.5rem 1rem}@media (min-width:48rem){.footer__bottomWrapper--AAtR-{justify-content:space-between;padding:1.5rem}}@media (min-width:90rem){.footer__bottomWrapper--AAtR-{flex-direction:row;padding:1.5rem 3rem}}</style>
#     <script>window.videojs = null</script>
#
#
#     <script>
#       window.__ENV__ = {"ROOT_URL":"https://fortune.com","API_ROOT_URL":"https://content.fortune.com/wp-json/irving/v1","NODE_ENV":"production"};
#     </script>
#
#     <script data-react-helmet="true" >
#             window.googletag.cmd.push(function () {
#               googletag.pubads().setTargeting('host', window.location.hostname);
#             });
#
#             // Nativo targeting
#             var kvpMap = {};
#             kvpMap['topics'] = 'fortune500,hub';
#             window.ntvConfig = window.ntvConfig || {} ;
#             window.ntvConfig.keyValues = kvpMap;
#           </script><script data-react-helmet="true" type="application/ld+json">{"@type":"NewsArticle","@context":"http://schema.org","publisher":{"@type":"Organization","name":"Fortune","logo":{"@type":"ImageObject","url":"https://fortune.com/static/media/logo.png"}},"headline":"Fortune 500","url":"https://fortune.com/fortune500/2021/","mainEntityOfPage":"https://fortune.com/fortune500/2021/","datePublished":"2021-06-01T11:32:17-04:00","dateModified":"2022-05-18T09:29:36-04:00","identifier":3040727,"isAccessibleForFree":false,"hasPart":{"@type":"WebPageElement","isAccessibleForFree":"False","cssSelector":".paywall"},"thumbnailUrl":"https://content.fortune.com/wp-content/uploads/2021/05/TTL.0721.Fortune-500-list-logo-featured.jpg","image":"https://content.fortune.com/wp-content/uploads/2021/05/TTL.0721.Fortune-500-list-logo-featured.jpg","author":[{"@type":"Person","name":"Fortune Editors","url":"https://fortune.com/author/fortune-editors/"}],"keywords":["Fortune 500"],"articleSection":"Uncategorized","faq":""}</script><script data-react-helmet="true" src="https://stats.wp.com/e-202238.js" defer="true" async="true"></script>
#
#
#     <script defer id="preload">
#       window.__PRELOADED_STATE__ = {"components":{"defaults":[{"name":"parsely","config":{"site":"fortune.com","metadata":{"@type":"WebPage","@context":"http://schema.org","publisher":{"@type":"Organization","name":"Fortune","logo":{"@type":"ImageObject","url":"https://fortune.com/static/media/logo.png"}}}},"children":[]},{"name":"fonts","config":{},"children":[]},{"name":"site-stats","config":{"data":{"blog":0,"post":0}},"children":[]},{"name":"head","config":{},"children":[{"name":"title","config":{},"children":["Fortune"]}]},{"name":"header","config":{"themeName":"large"},"children":[{"name":"header-search","config":{},"children":[{"name":"search-nav","config":{},"children":[{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757811,"label":"Automotives","url":"/section/auto/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757814,"label":"Careers","url":"/section/careers/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757815,"label":"Design","url":"/section/design/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757816,"label":"Energy","url":"/section/energy/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757820,"label":"Entertainment","url":"/section/entertainment/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757822,"label":"Finance","url":"/section/finance/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757823,"label":"Health","url":"/section/health/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757824,"label":"Humor","url":"/section/humor/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757825,"label":"International","url":"/section/international/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757830,"label":"Leadership","url":"/section/leadership/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757831,"label":"Photography","url":"/section/photography/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757832,"label":"Luxury","url":"/section/luxury/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757833,"label":"Newsletters","url":"/section/newsletters/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757839,"label":"Retail","url":"/section/retail/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757841,"label":"Real Estate","url":"/section/real-estate/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757843,"label":"Sports","url":"/section/sports/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757846,"label":"Technology","url":"/section/tech/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757849,"label":"All Rankings","url":"/rankings/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757851,"label":"Fortune 500","url":"/fortune500/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757853,"label":"Global 500","url":"/global500/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757855,"label":"40 Under 40","url":"/40-under-40/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757856,"label":"Most Powerful Women","url":"/most-powerful-women/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757860,"label":"About Us","url":"/about-us/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757861,"label":"Advertising","url":"https://fortunemediakit.com/","themeName":""},"children":[]}]}]}]},{"name":"header-menu","config":{"socialHeading":"Stay Connected"},"children":[{"name":"menu","config":{"location":"","title":"","titleLink":"","displayTitle":false,"menuItemClass":"","themeName":""},"children":[{"name":"menu-item","config":{"id":2659668,"label":"Rankings","url":"https://fortune.com/rankings/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757866,"label":"Magazine","url":"https://fortune.com/magazine/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757869,"label":"Newsletters","url":"https://mynewsletters.fortune.com/subscribe?source=FO_CMS_Nav","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2789243,"label":"Podcasts","url":"https://fortune.com/podcasts/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2821372,"label":"COVID-19","url":"https://fortune.com/tag/coronavirus/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757870,"label":"Video On Demand","url":"https://fortune.com/videos/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757871,"label":"Fortune Live Media","url":"https://fortune.com/conferences/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2939507,"label":"Fortune Connect","url":"https://fortune.com/connect","themeName":""},"children":[]},{"name":"menu-item","config":{"id":3024390,"label":"Fortune Education","url":"https://fortune.com/education/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":3326509,"label":"Fortune Well","url":"https://fortune.com/well/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":3374739,"label":"Fortune Crypto","url":"https://fortune.com/crypto/","themeName":""},"children":[]}]},{"name":"social-links","config":{"services":{"facebook":"Facebook","twitter":"Twitter","linkedin":"LinkedIn","instagram":"Instagram","pinterest":"Pinterest"},"displayIcons":true,"themeName":"menu-social"},"children":[{"name":"social-item","config":{"displayIcon":true,"type":"facebook","url":"https://www.facebook.com/FortuneMagazine/"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"twitter","url":"https://twitter.com/FortuneMagazine"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"linkedin","url":"https://www.linkedin.com/company/fortune-magazine"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"instagram","url":"https://www.instagram.com/fortunemag/"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"pinterest","url":"https://www.pinterest.com/fortunemagazine/"},"children":[]}]}]}]},{"name":"body","config":{},"children":[]},{"name":"footer","config":{},"children":[{"name":"footer-nav","config":{},"children":[{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2659710,"label":"40 Under 40","url":"/40-under-40/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2659711,"label":"100 Best Companies","url":"/best-companies/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2659712,"label":"Fortune 500","url":"/fortune500/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2659713,"label":"Global 500","url":"/global500/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757799,"label":"Most Powerful Women","url":"/most-powerful-women/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757800,"label":"World’s Greatest Leaders","url":"/worlds-greatest-leaders/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757801,"label":"World’s Most Admired Companies","url":"/worlds-most-admired-companies/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757802,"label":"See All Rankings","url":"/rankings/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757803,"label":"Finance","url":"/section/finance/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757804,"label":"Leadership","url":"/section/leadership/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757805,"label":"Success","url":"/section/success/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757806,"label":"Tech","url":"/section/tech/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757808,"label":"Asia","url":"/section/asia/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757809,"label":"Europe","url":"/section/europe/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757810,"label":"Environment","url":"/section/environment/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757813,"label":"Fortune Crypto","url":"https://fortune.com/crypto/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757817,"label":"Health","url":"/section/health/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757818,"label":"Well","url":"https://fortune.com/well/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757819,"label":"Retail","url":"/section/retail/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2770928,"label":"Lifestyle","url":"/section/lifestyle/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757821,"label":"Politics","url":"/section/politics/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757826,"label":"Newsletters","url":"/section/newsletters/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757827,"label":"Magazine","url":"/section/magazine/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757828,"label":"Features","url":"/section/features/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757829,"label":"Commentary","url":"/section/commentary/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757834,"label":"MPW","url":"/section/MPW/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757835,"label":"Conferences","url":"/section/conferences/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757836,"label":"Personal Finance","url":"/section/personal-finance/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2762173,"label":"Frequently Asked Questions","url":"https://fortune.com/customerservice/#faq","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757848,"label":"Customer Service Portal","url":"https://fortune.com/customerservice/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757852,"label":"Privacy Policy","url":"/privacy-policy/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757850,"label":"Terms of Use","url":"https://fortune.com/terms-of-use/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":3204278,"label":"Single Issues for Purchase","url":"https://order.emags.com/fortune_single_issues","themeName":""},"children":[]},{"name":"menu-item","config":{"id":3296226,"label":"International Print","url":"https://fortune.com/international-print-magazine-only-subscribers/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757837,"label":"FORTUNE Knowledge Group","url":"/section/fortune-knowledge-group/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757838,"label":"FORTUNE Branded Content","url":"https://customcontentonline.com/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757842,"label":"Fortune Data Store","url":"/data-store/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757845,"label":"Fortune Conferences","url":"https://fortuneconferences.com","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2762370,"label":"Advertising","url":"https://fortunemediakit.com/","themeName":""},"children":[]}]},{"name":"footer-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757857,"label":"About Us","url":"/about-us/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2770678,"label":"Work at Fortune","url":"https://fortune.com/fortune-careers/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757858,"label":"Behavioral Advertising Notice","url":"http://preferences-mgr.trustarc.com/?pid=fortunemedia01&aid=fortunemedia01_pub&type=fortunemedia","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757859,"label":"Terms and Conditions","url":"/terms-of-use/","themeName":""},"children":[]}]}]},{"name":"footer-disclaimer","config":{},"children":[{"name":"html","config":{"content":"\u003cp>© 2022 Fortune Media IP Limited. All Rights Reserved. Use of this site constitutes acceptance of our \u003ca href=\"https://fortune.com/terms-of-use/\">Terms of Use\u003c/a> and \u003ca href=\"https://fortune.com/privacy-policy/\">Privacy Policy\u003c/a> | \u003ca href=\"/california-privacy-policy/#notice\">CA Notice at Collection and Privacy Notice\u003c/a> | \u003ca href=\"https://submit-irm.trustarc.com/services/validation/156c4fed-e974-444a-8352-55333c91c0e6\">Do Not Sell My Personal Information\u003c/a> | \u003ca href=\"http://preferences-mgr.trustarc.com/?pid=fortunemedia01&amp;aid=fortunemedia01_pub&amp;type=fortunemedia\">Ad Choices \u003c/a>\u003cbr />\nFORTUNE is a trademark of Fortune Media IP Limited, registered in the U.S. and other countries. FORTUNE may receive compensation for some links to products and services on this website. Offers may be subject to change without notice.\u003cbr />\nS&amp;P Index data is the property of Chicago Mercantile Exchange Inc. and its licensors. All rights reserved. \u003ca href=\"https://www.intercontinentalexchange.com/terms-of-use\">Terms &amp; Conditions\u003c/a>. Powered and implemented by \u003ca href=\"https://www.interactivedata.com/idms\">Interactive Data Managed Solutions\u003c/a>.\u003c/p>\n"},"children":[]}]},{"name":"social-links","config":{"services":{"facebook":"Facebook","twitter":"Twitter","linkedin":"LinkedIn","instagram":"Instagram","pinterest":"Pinterest"},"displayIcons":true,"themeName":"footer"},"children":[{"name":"social-item","config":{"displayIcon":true,"type":"facebook","url":"https://www.facebook.com/FortuneMagazine/","themeName":"footer"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"twitter","url":"https://twitter.com/FortuneMagazine","themeName":"footer"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"linkedin","url":"https://www.linkedin.com/company/fortune-magazine","themeName":"footer"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"instagram","url":"https://www.instagram.com/fortunemag/","themeName":"footer"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"pinterest","url":"https://www.pinterest.com/fortunemagazine/","themeName":"footer"},"children":[]}]}]}],"providers":{"/fortune500/2021/search/":[{"name":"google-tag-manager","config":{"containerId":"GTM-N68KRG3","dataLayer":{"contentType":"franchise-list","contentId":null,"channel":"fortune500","tags":[],"headline":null,"authors":[],"franchiseName":"Fortune 500","premiumCategory":"legacy","topics":["fortune500"],"sections":null,"publishDate":null}},"children":[]},{"name":"franchise-config-provider","config":{"franchise":"fortune500","franchiseTitle":"Fortune 500","franchiseListPath":"https://fortune.com/fortune500/2021","color":"#d0ac44"},"children":[]},{"name":"advertising-provider","config":{"ctype":"franchise","cid":"","ch":"fortune500","debug":false,"search":null,"tags":null,"topics":["fortune500","hub"],"premiumCategory":null,"defaultPath":"fortune","slots":[{"placementName":"Leaderboard","slotId":"Leaderboard0","lazyload":false,"useDynamicChannel":false,"targeting":{"placement_name":"Leaderboard","index":1}}]},"children":[]}]},"page":{"/fortune500/2021/search/":[{"name":"head","config":{},"children":[{"name":"title","config":{},"children":["Fortune 500 list of companies 2021 | Fortune"]},{"name":"script","config":{"src":"https://stats.wp.com/e-202238.js","defer":true,"async":true},"children":[]},{"name":"meta","config":{"name":"description","content":"This year’s Fortune 500 marks the 67th running of the list."},"children":[]},{"name":"meta","config":{"name":"keywords","content":""},"children":[]},{"name":"meta","config":{"property":"og:url","content":"https://fortune.com/fortune500/2021/"},"children":[]},{"name":"meta","config":{"property":"og:type","content":"article"},"children":[]},{"name":"meta","config":{"property":"og:title","content":"Fortune 500"},"children":[]},{"name":"meta","config":{"property":"og:description","content":"This year’s Fortune 500 marks the 67th running of the list."},"children":[]},{"name":"meta","config":{"property":"og:site_name","content":"Fortune"},"children":[]},{"name":"meta","config":{"property":"fb:pages","content":"56501027948"},"children":[]},{"name":"meta","config":{"property":"og:image","content":"https://content.fortune.com/wp-content/uploads/2021/05/TTL.0721.Fortune-500-list-logo-featured.jpg?resize=1200,600"},"children":[]},{"name":"meta","config":{"property":"og:width","content":"1024"},"children":[]},{"name":"meta","config":{"property":"og:height","content":"683"},"children":[]},{"name":"meta","config":{"name":"twitter:card","content":"summary_large_image"},"children":[]},{"name":"meta","config":{"name":"twitter:title","content":"Fortune 500"},"children":[]},{"name":"meta","config":{"name":"twitter:description","content":"This year’s Fortune 500 marks the 67th running of the list."},"children":[]},{"name":"meta","config":{"name":"twitter:image","content":"https://content.fortune.com/wp-content/uploads/2021/05/TTL.0721.Fortune-500-list-logo-featured.jpg?resize=1200,600"},"children":[]},{"name":"meta","config":{"name":"twitter:url","content":"https://fortune.com/fortune500/2021/"},"children":[]},{"name":"link","config":{"rel":"preload","href":"/static/media/Graphik-Bold-Web.woff2","as":"font","type":"font/woff2","crossorigin":"anonymous"},"children":[]},{"name":"link","config":{"rel":"preload","href":"/static/media/GraphikCondensed-Bold-Web.woff2","as":"font","type":"font/woff2","crossorigin":"anonymous"},"children":[]},{"name":"link","config":{"rel":"preload","href":"/static/media/SaolText-Bold.woff2","as":"font","type":"font/woff2","crossorigin":"anonymous"},"children":[]},{"name":"link","config":{"rel":"canonical","href":"https://fortune.com/fortune500/2021/"},"children":[]}]},{"name":"parsely","config":{"site":"fortune.com","metadata":{"@type":"NewsArticle","@context":"http://schema.org","publisher":{"@type":"Organization","name":"Fortune","logo":{"@type":"ImageObject","url":"https://fortune.com/static/media/logo.png"}},"headline":"Fortune 500","url":"https://fortune.com/fortune500/2021/","mainEntityOfPage":"https://fortune.com/fortune500/2021/","datePublished":"2021-06-01T11:32:17-04:00","dateModified":"2022-05-18T09:29:36-04:00","identifier":3040727,"isAccessibleForFree":false,"hasPart":{"@type":"WebPageElement","isAccessibleForFree":"False","cssSelector":".paywall"},"thumbnailUrl":"https://content.fortune.com/wp-content/uploads/2021/05/TTL.0721.Fortune-500-list-logo-featured.jpg","image":"https://content.fortune.com/wp-content/uploads/2021/05/TTL.0721.Fortune-500-list-logo-featured.jpg","author":[{"@type":"Person","name":"Fortune Editors","url":"https://fortune.com/author/fortune-editors/"}],"keywords":["Fortune 500"],"articleSection":"Uncategorized","faq":""}},"children":[]},{"name":"fonts","config":{},"children":[]},{"name":"site-stats","config":{"data":{"v":"ext","j":"1:11.3.1","blog":197693856,"post":"0","tz":-4,"srv":"content.fortune.com"}},"children":[]},{"name":"header","config":{"themeName":"large","homeLink":"https://fortune.com/fortune500/2021/"},"children":[{"name":"header-search","config":{},"children":[{"name":"search-nav","config":{},"children":[{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757811,"label":"Automotives","url":"/section/auto/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757814,"label":"Careers","url":"/section/careers/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757815,"label":"Design","url":"/section/design/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757816,"label":"Energy","url":"/section/energy/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757820,"label":"Entertainment","url":"/section/entertainment/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757822,"label":"Finance","url":"/section/finance/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757823,"label":"Health","url":"/section/health/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757824,"label":"Humor","url":"/section/humor/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757825,"label":"International","url":"/section/international/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757830,"label":"Leadership","url":"/section/leadership/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757831,"label":"Photography","url":"/section/photography/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757832,"label":"Luxury","url":"/section/luxury/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757833,"label":"Newsletters","url":"/section/newsletters/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757839,"label":"Retail","url":"/section/retail/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757841,"label":"Real Estate","url":"/section/real-estate/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757843,"label":"Sports","url":"/section/sports/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757846,"label":"Technology","url":"/section/tech/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757849,"label":"All Rankings","url":"/rankings/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757851,"label":"Fortune 500","url":"/fortune500/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757853,"label":"Global 500","url":"/global500/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757855,"label":"40 Under 40","url":"/40-under-40/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757856,"label":"Most Powerful Women","url":"/most-powerful-women/","themeName":""},"children":[]}]},{"name":"search-nav-menu","config":{},"children":[{"name":"menu-item","config":{"id":2757860,"label":"About Us","url":"/about-us/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757861,"label":"Advertising","url":"https://fortunemediakit.com/","themeName":""},"children":[]}]}]}]},{"name":"header-menu","config":{"socialHeading":"Stay Connected"},"children":[{"name":"menu","config":{"location":"","title":"","titleLink":"","displayTitle":false,"menuItemClass":"","themeName":""},"children":[{"name":"menu-item","config":{"id":2659668,"label":"Rankings","url":"https://fortune.com/rankings/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757866,"label":"Magazine","url":"https://fortune.com/magazine/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757869,"label":"Newsletters","url":"https://mynewsletters.fortune.com/subscribe?source=FO_CMS_Nav","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2789243,"label":"Podcasts","url":"https://fortune.com/podcasts/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2821372,"label":"COVID-19","url":"https://fortune.com/tag/coronavirus/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757870,"label":"Video On Demand","url":"https://fortune.com/videos/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2757871,"label":"Fortune Live Media","url":"https://fortune.com/conferences/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":2939507,"label":"Fortune Connect","url":"https://fortune.com/connect","themeName":""},"children":[]},{"name":"menu-item","config":{"id":3024390,"label":"Fortune Education","url":"https://fortune.com/education/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":3326509,"label":"Fortune Well","url":"https://fortune.com/well/","themeName":""},"children":[]},{"name":"menu-item","config":{"id":3374739,"label":"Fortune Crypto","url":"https://fortune.com/crypto/","themeName":""},"children":[]}]},{"name":"social-links","config":{"services":{"facebook":"Facebook","twitter":"Twitter","linkedin":"LinkedIn","instagram":"Instagram","pinterest":"Pinterest"},"displayIcons":true,"themeName":"menu-social"},"children":[{"name":"social-item","config":{"displayIcon":true,"type":"facebook","url":"https://www.facebook.com/FortuneMagazine/"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"twitter","url":"https://twitter.com/FortuneMagazine"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"linkedin","url":"https://www.linkedin.com/company/fortune-magazine"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"instagram","url":"https://www.instagram.com/fortunemag/"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"pinterest","url":"https://www.pinterest.com/fortunemagazine/"},"children":[]}]}]},{"name":"html","config":{"content":"Fortune 500"},"children":[]},{"name":"social-sharing","config":{"services":{"facebook":true,"twitter":true,"linkedin":true,"email":true},"displayIcons":true,"themeName":"header"},"children":[{"name":"social-item","config":{"displayIcon":true,"type":"facebook","url":"https://www.facebook.com/sharer.php/?u=https%3A%2F%2Ffortune.com%2Ffortune500%2F2021%2F","themeName":"header"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"twitter","url":"https://twitter.com/intent/tweet?text=Fortune%20500&url=https%3A%2F%2Ffortune.com%2Ffortune500%2F2021%2F","themeName":"header"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"linkedin","url":"https://www.linkedin.com/shareArticle/?url=https%3A%2F%2Ffortune.com%2Ffortune500%2F2021%2F&title=Fortune%20500&summary=This%20year%E2%80%99s%20Fortune%20500%20marks%20the%2067th%20running%20of%20the%20list.","themeName":"header"},"children":[]},{"name":"social-item","config":{"displayIcon":true,"type":"email","url":"mailto:?subject=Fortune%20500&body=https%3A%2F%2Ffortune.com%2Ffortune500%2F2021%2F","themeName":"header"},"children":[]}]},{"name":"advertising-slot","config":{"align":"center","lazyload":false,"useDynamicChannel":false,"placementName":"Leaderboard","slotId":"Leaderboard0","targeting":{"placement_name":"Leaderboard","index":1}},"children":[]},{"name":"menu","config":{"location":"","title":"","titleLink":"","displayTitle":false,"menuItemClass":"","themeName":"header"},"children":[{"name":"menu-item","config":{"id":2659660,"label":"Rankings","url":"","themeName":"header"},"children":[{"name":"menu","config":{"location":"","title":"Rankings","titleLink":"","displayTitle":false,"menuItemClass":"","themeName":"","type":"submenu"},"children":[{"name":"menu-item","config":{"id":2757862,"label":"See All Rankings","url":"https://fortune.com/rankings/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2757863,"label":"Fortune 500","url":"https://fortune.com/fortune500/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2757864,"label":"Global 500","url":"https://fortune.com/global500/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2757865,"label":"40 Under 40","url":"https://fortune.com/40-under-40/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2965880,"label":"GREAT PLACE TO WORK LISTS","url":"https://fortune.com/great-place-to-work-rankings/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":3024473,"label":"Best MBA Programs","url":"https://fortune.com/education/business/mba/rankings/best-mba-programs/","themeName":"header"},"children":[]}]}]},{"name":"menu-item","config":{"id":2757840,"label":"Magazine","url":"https://fortune.com/magazine/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2662045,"label":"Newsletters","url":"https://mynewsletters.fortune.com/subscribe?source=FO_CMS_Nav","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2783994,"label":"Podcasts","url":"https://fortune.com/podcasts/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2939509,"label":"More","url":"","themeName":"header"},"children":[{"name":"menu","config":{"location":"","title":"More","titleLink":"","displayTitle":false,"menuItemClass":"","themeName":"","type":"submenu"},"children":[{"name":"menu-item","config":{"id":2808973,"label":"Video On Demand","url":"https://fortune.com/videos/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2662044,"label":"Fortune Live Media","url":"https://fortune.com/conferences/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":2939511,"label":"Fortune Connect","url":"https://fortune.com/connect","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":3024258,"label":"Fortune Education","url":"https://fortune.com/education/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":3326507,"label":"Fortune Well","url":"https://fortune.com/well/","themeName":"header"},"children":[]},{"name":"menu-item","config":{"id":3374737,"label":"Fortune Crypto","url":"https://fortune.com/crypto/","themeName":"header"},"children":[]}]}]}]}]},{"name":"body","config":{},"children":[{"name":"franchise-search-wrapper","config":{"endpoint":"franchise-search-results?list_id=3040727","title":"Fortune 500","years":{"name":"franchise-year-nav","config":{"year":"2021","years":{"1996":"https://fortune.com/fortune500/1996/search/","1997":"https://fortune.com/fortune500/1997/search/","1998":"https://fortune.com/fortune500/1998/search/","1999":"https://fortune.com/fortune500/1999/search/","2000":"https://fortune.com/fortune500/2000/search/","2001":"https://fortune.com/fortune500/2001/search/","2002":"https://fortune.com/fortune500/2002/search/","2003":"https://fortune.com/fortune500/2003/search/","2004":"https://fortune.com/fortune500/2004/search/","2005":"https://fortune.com/fortune500/2005/search/","2006":"https://fortune.com/fortune500/2006/search/","2007":"https://fortune.com/fortune500/2007/search/","2008":"https://fortune.com/fortune500/2008/search/","2009":"https://fortune.com/fortune500/2009/search/","2010":"https://fortune.com/fortune500/2010/search/","2011":"https://fortune.com/fortune500/2011/search/","2012":"https://fortune.com/fortune500/2012/search/","2013":"https://fortune.com/fortune500/2013/search/","2014":"https://fortune.com/fortune500/2014/search/","2015":"https://fortune.com/fortune500/2015/search/","2016":"https://fortune.com/fortune500/2016/search/","2017":"https://fortune.com/fortune500/2017/search/","2018":"https://fortune.com/fortune500/2018/search/","2019":"https://fortune.com/fortune500/2019/search/","2020":"https://fortune.com/fortune500/2020/search/","2021":"https://fortune.com/fortune500/2021/search/","2022":"https://fortune.com/fortune500/2022/search/"},"themeName":"search"},"children":[]}},"children":[]}]}]}},"componentData":{},"error":null,"loading":false,"player":{"currentTime":0,"duration":0,"loading":false,"playing":false,"seek":0,"src":"","visible":false,"volume":0.5},"route":{"status":200,"redirectTo":"","redirectStatus":0,"action":"PUSH","pathname":"/fortune500/2021/search/","search":"?","hash":""},"visible":{"search":false,"primaryNav":false,"freestar":false,"adminBar":false},"contactForm":{"submitting":false,"submitted":false,"failed":false,"validation":{},"redirect":""},"user":{"isLoggedIn":false,"accessLevel":null}};
#     </script>
#
#
#     <script defer>
#       window.__CRITICAL_CSS_STYLE_LOADER_KEYS__ = {"3994eebbbcbeef9cd9021140c03bf63a":true,"4e24d87e0b8b53b410f023066dd657be":true,"d3def5676476b829ee3cb2e5831458c5":true,"49a06b23990c68bfe6f1cb5ab93beb18":true,"f88bdd23aa010f48184a31d2b81b235a":true,"1e548d11003f81311d533eb7948dee8f":true,"e3460d1b4cb10dd2d87592fd50b556c1":true,"34169b2ba6c9448b54eed88ab5a2365a":true,"27684f445d3dc04e776773f121c48edf":true,"62900ce0963e8dc7fd4f4dd127fce429":true,"3a443e183738848115dc3f2e4b8a4c6a":true,"732330311266b22a134e017885ce63cb":true,"83db1fb161017471a16a02a7037e333e":true,"cf9c72eeea9f5591c0d2ff7b83970773":true,"4cae48368a02362a44ec09dc9e69ba0c":true};
#     </script>
#
#
#
#       <script defer >!function(e){function r(r){for(var n,i,a=r[0],c=r[1],l=r[2],p=0,s=[];p<a.length;p++)i=a[p],Object.prototype.hasOwnProperty.call(o,i)&&o[i]&&s.push(o[i][0]),o[i]=0;for(n in c)Object.prototype.hasOwnProperty.call(c,n)&&(e[n]=c[n]);for(f&&f(r);s.length;)s.shift()();return u.push.apply(u,l||[]),t()}function t(){for(var e,r=0;r<u.length;r++){for(var t=u[r],n=!0,a=1;a<t.length;a++){var c=t[a];0!==o[c]&&(n=!1)}n&&(u.splice(r--,1),e=i(i.s=t[0]))}return e}var n={},o={82:0},u=[];function i(r){if(n[r])return n[r].exports;var t=n[r]={i:r,l:!1,exports:{}};return e[r].call(t.exports,t,t.exports,i),t.l=!0,t.exports}i.e=function(e){var r=[],t=o[e];if(0!==t)if(t)r.push(t[2]);else{var n=new Promise((function(r,n){t=o[e]=[r,n]}));r.push(t[2]=n);var u,a=document.createElement("script");a.charset="utf-8",a.timeout=120,i.nc&&a.setAttribute("nonce",i.nc),a.src=function(e){return i.p+"static/js/"+({4:"index"}[e]||e)+".chunk.js?v="+{4:"d6abcb2d"}[e]}(e);var c=new Error;u=function(r){a.onerror=a.onload=null,clearTimeout(l);var t=o[e];if(0!==t){if(t){var n=r&&("load"===r.type?"missing":r.type),u=r&&r.target&&r.target.src;c.message="Loading chunk "+e+" failed.\n("+n+": "+u+")",c.name="ChunkLoadError",c.type=n,c.request=u,t[1](c)}o[e]=void 0}};var l=setTimeout((function(){u({type:"timeout",target:a})}),12e4);a.onerror=a.onload=u,document.head.appendChild(a)}return Promise.all(r)},i.m=e,i.c=n,i.d=function(e,r,t){i.o(e,r)||Object.defineProperty(e,r,{enumerable:!0,get:t})},i.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},i.t=function(e,r){if(1&r&&(e=i(e)),8&r)return e;if(4&r&&"object"==typeof e&&e&&e.__esModule)return e;var t=Object.create(null);if(i.r(t),Object.defineProperty(t,"default",{enumerable:!0,value:e}),2&r&&"string"!=typeof e)for(var n in e)i.d(t,n,function(r){return e[r]}.bind(null,n));return t},i.n=function(e){var r=e&&e.__esModule?function(){return e.default}:function(){return e};return i.d(r,"a",r),r},i.o=function(e,r){return Object.prototype.hasOwnProperty.call(e,r)},i.p="https://fortune.com/",i.oe=function(e){throw console.error(e),e};var a=window.webpackJsonp=window.webpackJsonp||[],c=a.push.bind(a);a.push=r,a=a.slice();for(var l=0;l<a.length;l++)r(a[l]);var f=c;t()}([]);
# //# sourceMappingURL=https://fortune.com/static/js/runtime~main.map?v=f2290997</script>
#
#
#
#       <link
#         rel="preload"
#         href="https://fortune.com/static/js/main.chunk.js?v=e07877c7-uuid3-79"
#         as="script"
#       >
#
#       <script defer src="https://fortune.com/static/js/main.chunk.js?v=e07877c7-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.css-loader.chunk.js?v=56515269-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.lodash.chunk.js?v=5976f1e3-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.babel.chunk.js?v=771f486c-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.babel-plugin-universal-import.chunk.js?v=97e373cc-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.base64-js.chunk.js?v=8af14940-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.blueimp-md5.chunk.js?v=d8d5dbcc-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.buffer.chunk.js?v=038ac162-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.classnames.chunk.js?v=c854ec01-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.core-js.chunk.js?v=aed661d4-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.critical-style-loader.chunk.js?v=723bd6d5-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.crypto-js.chunk.js?v=a26cfec2-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.d3-ease.chunk.js?v=abe9ba6b-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.d3-timer.chunk.js?v=8f55c0d5-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.date-fns.chunk.js?v=f2980e40-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.debug.chunk.js?v=be215233-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.decode-uri-component.chunk.js?v=6fbc58a2-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.dom-helpers.chunk.js?v=fd2513f2-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.exenv.chunk.js?v=3161ad93-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.history.chunk.js?v=70d10101-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.hoist-non-react-statics.chunk.js?v=bb6d3777-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.ieee754.chunk.js?v=7d010976-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.invariant.chunk.js?v=da04bd6a-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.isarray.chunk.js?v=3852c445-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.isomorphic-fetch.chunk.js?v=bb5c1023-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.js-cookie.chunk.js?v=a3f22fa7-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.kapellmeister.chunk.js?v=2367edc2-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.loadable.chunk.js?v=c20a705f-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.localforage.chunk.js?v=0a33f3bc-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.ms.chunk.js?v=a339176a-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.nuka-carousel.chunk.js?v=67d3c545-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.object-assign.chunk.js?v=17dd00aa-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.path-browserify.chunk.js?v=e13e572b-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.process.chunk.js?v=a25b69b7-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.prop-types.chunk.js?v=877fe665-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.query-string.chunk.js?v=bba159cc-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.querystringify.chunk.js?v=f467d9a0-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react.chunk.js?v=dbe9d679-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-async-script.chunk.js?v=2bbbb931-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-dom.chunk.js?v=4f0ba6b7-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-fast-compare.chunk.js?v=803dd3c0-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-google-recaptcha.chunk.js?v=0684e52e-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-helmet.chunk.js?v=89b907f5-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-hot-loader.chunk.js?v=aebd6dd4-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-intersection-observer.chunk.js?v=b02f748e-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-is.chunk.js?v=e05febfb-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-lazy-load-image-component.chunk.js?v=9822aed3-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-lifecycles-compat.chunk.js?v=553d4106-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-move.chunk.js?v=302219b6-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-redux.chunk.js?v=cb461c15-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-side-effect.chunk.js?v=5c47d8ff-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-table.chunk.js?v=3d5521a5-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-transition-group.chunk.js?v=8379ac96-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.react-use-form-state.chunk.js?v=6ef378b2-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.reduce-reducers.chunk.js?v=d18dcdf9-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.redux.chunk.js?v=ef7ab16c-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.redux-devtools-extension.chunk.js?v=539ae386-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.redux-persist.chunk.js?v=f74c7ead-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.redux-saga.chunk.js?v=76361749-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.regenerator-runtime.chunk.js?v=c0a830b6-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.requires-port.chunk.js?v=4c507fea-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.reselect.chunk.js?v=27107efe-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.resolve-pathname.chunk.js?v=c55c91e5-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.sanitize-html.chunk.js?v=3f9f5b0a-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.scheduler.chunk.js?v=39f1979b-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.strict-uri-encode.chunk.js?v=2369675a-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.style-loader.chunk.js?v=c8746107-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.symbol-observable.chunk.js?v=e7ae46f7-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.tiny-invariant.chunk.js?v=0c693822-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.url-parse.chunk.js?v=f65c2894-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.value-equal.chunk.js?v=74f29239-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.web-vitals.chunk.js?v=8eec187b-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.webpack.chunk.js?v=7d5090f1-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.whatwg-fetch.chunk.js?v=29cec37b-uuid3-79"></script>
#
#       <script defer src="https://fortune.com/static/js/npm.wicg-inert.chunk.js?v=f8b506c6-uuid3-79"></script>
#
#
#     <script>
#       var isWechat = navigator.userAgent.includes("MicroMessenger");
#       if (isWechat) {
#         var script = document.createElement("script");
#         script.onload = () => {
#           var g_url = window.location.href;
#           var g_title = document.querySelector('title').text;
#           var g_shareimg = "https://content.fortune.com/wp-content/uploads/2020/02/favicon_144.ico";
#           var g_desc = document.querySelector('meta[property="og:description"]').content;
#
#           WeChat(g_url, g_title, g_shareimg, g_desc);
#
#           function WeChat(url, title, img, desc) {
#             fetch("https://www.caifuzhongwen.com/500api/getConfig.do?url=" + encodeURIComponent(encodeURIComponent(location.href)), { mode: "cors" })
#             .then((response) => response.json())
#             .then(function (data) {
#                 signPackage = data;
#                 wx.config(data);
#                 wx.ready(function () {
#                     wx.updateTimelineShareData({
#                         title: title,
#                         link: url,
#                         imgUrl: img,
#                         success: function () {},
#                         cancel: function () {}
#                     });
#                     wx.updateAppMessageShareData({
#                         title: title,
#                         desc: desc,
#                         link: url,
#                         imgUrl: img,
#                         success: function () {},
#                         cancel: function () {}
#                     });
#                     wx.error(function (res) {
#                         //location.href = g_url;
#                     });
#                 });
#             })
#           }
#         };
#         script.src = "https://res.wx.qq.com/open/js/jweixin-1.6.0.js";
#         document.head.appendChild(script);
#       }
#     </script>
# </head>
# <body class="site-wrapper">
# <noscript>
#     You need to enable JavaScript to view this site.
# </noscript>
#
# <div id="root"><div><a href="#content" class="app__skipLink--z5h7i">Skip to Content</a><noscript><iframe title="fortune-gtm" src="https://www.googletagmanager.com/ns.html?id=GTM-N68KRG3" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><fonts></fonts><div class="header__adWrapper--hK8Xq header__slideUpLarge--dJYzB"><div id="Leaderboard0" class="adTag__Leaderboard--2bO6j fortune-ad-tag__leaderboard" align="center"></div></div><div class="header__bottom--14eUZ"><div class="container__xxl--3SCes container__container--a5NXK header__bottomContent--28Yr8 container__padding--2mKn5"><div class="header__bottomMenu--gkHu_"><div class="header__bottomLeft--19Wnh"></div><div class="header__bottomCenter--M0puQ"><div class="header__menu--2nvJG"><ul class="menu__header--3hepL"><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="">Rankings</a><ul class=""><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/rankings/">See All Rankings</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/fortune500/">Fortune 500</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/global500/">Global 500</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/40-under-40/">40 Under 40</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/great-place-to-work-rankings/">GREAT PLACE TO WORK LISTS</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/education/business/mba/rankings/best-mba-programs/">Best MBA Programs</a></li></ul></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/magazine/">Magazine</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://mynewsletters.fortune.com/subscribe?source=FO_CMS_Nav">Newsletters</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/podcasts/">Podcasts</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="">More</a><ul class=""><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/videos/">Video On Demand</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/conferences/">Fortune Live Media</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/connect">Fortune Connect</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/education/">Fortune Education</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/well/">Fortune Well</a></li><li class="menuItem__wrapper--2F3dl menuItem__header--1S8Gp"><a trackerdata="[object Object]" href="https://fortune.com/crypto/">Fortune Crypto</a></li></ul></li></ul></div></div></div><div class="header__bottomRight--3f8BV"><div><button id="old-search" class="headerSearch__openButton--3wTuY" type="button"><label for="queryly_toggle">SEARCH</label></button></div><div><button id="new-search" class="headerSearch__openButton--3wTuY headerSearch__openButtonSearch--3q6mX" type="button"><label for="queryly_toggle"><svg viewBox="0 0 23 23"><path d="M8.198 14.36c1.573 0 2.91-.55 4.011-1.65 1.101-1.102 1.652-2.439 1.652-4.012 0-1.572-.55-2.91-1.652-4.01-1.1-1.101-2.438-1.652-4.01-1.652-1.573 0-2.91.55-4.011 1.652-1.101 1.1-1.652 2.438-1.652 4.01 0 1.573.55 2.91 1.652 4.011 1.1 1.101 2.438 1.652 4.01 1.652zm7.55 0L22 20.614 20.113 22.5l-6.252-6.252v-1.003l-.354-.354c-1.494 1.298-3.264 1.947-5.309 1.947-2.28 0-4.217-.787-5.81-2.36C.797 12.907 0 10.98 0 8.699c0-2.28.796-4.217 2.389-5.81C3.98 1.297 5.918.5 8.199.5c2.28 0 4.207.796 5.78 2.389 1.572 1.592 2.359 3.529 2.359 5.81 0 2.044-.649 3.814-1.947 5.308l.354.354h1.003z" fill="#FFF" fill-rule="nonzero"></path></svg><span>SEARCH</span></label></button><span class="headerSearch__tag--2438f">NEW</span><div class="headerSearch__tagContainer--2nXOp"><div>A vastly improved search engine helps you find the latest on companies, business leaders, and news more easily.</div></div></div><div class="headerAccount__wrapper--2w_kq"><div class="headerAccount__text1--th-Rr" role="button" tabindex="0">SIGN IN</div></div></div></div></div><div class="header__placeholder--2_VsK undefined header__withoutAd--1276a"></div><main id="content"><div id="piano-wrapper"><div id="piano-inline"></div></div><div class="searchWrapper__headerContainer--10iGf"><h1 class="heading__step-up-three--4WDO6 heading__heading--hUYqy heading__graphikCond--38qNM heading__franchise--3Gdva"><span>Fortune 500</span></h1></div></main></div></div>
# </body>
# </html>
# Out:
# Writing fortune.html

# %%
# ler o arquivo fortune.html

from bs4 import BeautifulSoup

pagina = BeautifulSoup(open('fortune.html', mode='r'), 'html.parser')
print(pagina)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="https://content.fortune.com/wp-content/uploads/2020/02/favicon_144.ico" rel="shortcut icon"/>
# <!-- @todo perhaps make GTM ID an env var instead of a setting, use here instead of hard-coding. -->
# <!-- 3rd party dns-prefetching -->
# <link crossorigin="" href="https://cdn.ampproject.org" rel="preconnect"/>
# <link crossorigin="" href="https://buy.tinypass.com" rel="preconnect"/>
# <link crossorigin="" href="https://static.adsafeprotected.com" rel="preconnect"/>
# <link crossorigin="" href="https://content.fortune.com" rel="preconnect"/>
# <link crossorigin="" href="https://download.fortune.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/>
# ...

# %%
# extrair as linhas da tabela
tabela = pagina.find('div', {'class': 'rt-table'})
linhas = tabela.find('div', {'class': 'rt-tbody'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-ddbb6cdbe5a6> in <module>
#       1 # extrair as linhas da tabela
#       2 tabela = pagina.find('div', {'class': 'rt-table'})
# ----> 3 linhas = tabela.find('div', {'class': 'rt-tbody'})
#       4
#       5
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# extrair o conteudo das linhas da tabela

for linha in linhas:
  colunas = linha.find('div', {'role': 'row'})
  ... # continue o codigo aqui

# %%
# escrever o conteudo extraido no arquivo fortune.csv
# utilize a variavel header para construir a o cabecalho do arquivo csv

header = [
  'rank', 
  'name', 
  'revenues', 
  'revenues-percent-change', 
  'profits', 
  'profits-percent-change', 
  'assets', 
  'market-value',
  'employees'
]

... # continue o codigo aqui

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Data Wrangling

# %% [markdown]
# ### **2.1. Criando o DataFrame**

# %% [markdown]
# Crie o dataframe Pandas na variável `fortune_df` através da leitura do arquivo `fortune.csv`

# %%
fortune_df = ... # continue o codigo aqui

# %% [markdown]
# ### **2.2. Explorando o DataFrame**

# %% [markdown]
# Utilizando os métodos vistos em aula, explore o dataframe.

# %% [markdown]
#  - Liste as 10 primeiras linhas do dataframe:

# %%
... # continue o codigo aqui

# %% [markdown]
#  - Liste os tipos de dados armazenados na coluna do dataframe:

# %%
... # continue o codigo aqui

# %% [markdown]
#  - Liste o numero de linhas e colunas do dataframe:

# %%
... # continue o codigo aqui

# %% [markdown]
# ### **2.3. Limpando o DataFrame**

# %% [markdown]
# Grande parte das colunas numéricas (exceto a coluna `ranking` e `employees`) possuem o caracter `$` ou `%` que as classificam com o tipo `object` (ou `str` do Python) ao invés do tipo correto como `int` ou `float`. Utilizando os métodos de atualizam, remova os caracteres das linhas das colunas numéricas.

# %%
... # continue o codigo aqui

# %% [markdown]
# **Dica**: Você pode utilizar qualquer método de atualização, eu recomendo o uso do método `apply`.

# %% [markdown]
# ### **2.4. Salvando o DataFrame**

# %% [markdown]
# Utilize o método `to_csv` para salvar o dataframe `fortune_df` no arquivo `fortune-limpo.csv`.

# %%
... # continue o codigo aqui

# %% [markdown]
# **Dica**: Confira a documentação oficial do método `to_csv` neste [link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html).

# %% [markdown]
# ---
